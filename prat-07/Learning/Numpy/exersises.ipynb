# %% [markdown]
# **General Questions**

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.
data.shape
# Out:
# (5, 3)

# %%
#Find the average age of students.
st_mean = data[:, 0].mean()
print(st_mean)
# Out:
# 18.4

# %%
#Extract Math marks of all students.
math_marks = data[:,1]
print(math_marks)
# Out:
# [85 92 76 65 90]

# %%
#Find the highest Science mark.
print(data[:,2].max())
# Out:
# 95

# %%
#Get details of the student who scored more than 90 in Math.
data[data[:,1] > 90]
# Out:
# array([[19, 92, 88]])

# %%
#Increase Math marks of all students by 5.
data[:,1] + 5
# Out:
# array([90, 97, 81, 70, 95])

# %%
#Find how many students are younger than 19.
data[data[:,0] < 19]
# Out:
# array([[18, 85, 78],
#        [17, 76, 95],
#        [18, 65, 70]])

# %%
#Calculate the average marks in each subject (column-wise mean).
print(data[:,1].mean())
print(data[:,2].mean())
# Out:
# 81.6
# 83.2

# %%
#Get data of students who scored at least 80 in both subjects.
maths_gt_80 = data[:,1] > 80
science_gt_80 = data[:,2] > 80

data[maths_gt_80 & science_gt_80]
# Out:
# array([[19, 92, 88],
#        [20, 90, 85]])

# %%
#Replace all Science marks < 75 with 0.
data[:,2][data[:,2] < 75] = 0
data
# Out:
# array([[18, 85, 78],
#        [19, 92, 88],
#        [17, 76, 95],
#        [18, 65,  0],
#        [20, 90, 85]])
